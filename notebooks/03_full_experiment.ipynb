# %% [markdown]
# # Full Experiment Demo
#
# Run a reduced experiment and generate the summary statistics.

# %%
from affect_aif.analysis.metrics import final_round_summary
from affect_aif.experiment.config import ExperimentConfig
from affect_aif.experiment.runner import ExperimentRunner

cfg = ExperimentConfig(num_rounds=20, num_replications=3, calibration_episodes=2)
runner = ExperimentRunner(cfg)
results = runner.run_all()
final_round_summary(results)
