# %% [markdown]
# # Affective Agent Demo
#
# Inspect the shallow affective condition and the derived `mu`.

# %%
from affect_aif.experiment.config import ExperimentConfig
from affect_aif.experiment.runner import ExperimentRunner

cfg = ExperimentConfig(num_rounds=20, num_replications=1, calibration_episodes=2, conditions=[2])
runner = ExperimentRunner(cfg)
results = runner.run_all()
runner.calibration_summary, results[['round', 'betas', 'prediction_errors']].head()
