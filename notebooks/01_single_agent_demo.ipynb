# %% [markdown]
# # Single-Agent Trust Game Demo
#
# Minimal walkthrough for a deep-planning baseline agent.

# %%
from affect_aif.experiment.config import ExperimentConfig
from affect_aif.experiment.runner import ExperimentRunner

cfg = ExperimentConfig(num_rounds=10, num_replications=1, calibration_episodes=1, conditions=[1])
runner = ExperimentRunner(cfg)
results = runner.run_all()
results.head()
